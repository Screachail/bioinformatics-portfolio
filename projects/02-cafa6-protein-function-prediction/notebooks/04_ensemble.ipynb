# %%
import numpy as np
import xgboost as xgb
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import f1_score
import joblib
import json

print("=" * 80)
print("🎯 ENSEMBLE & SUBMISSION GENERATION")
print("=" * 80)

# Load data
X_train = np.load("../data/gold/X_train_esm2.npy")
X_val = np.load("../data/gold/X_train_esm2.npy")  # Ten sam plik, ale inne indeksy
y_train = np.load("../data/gold/y_train_labels.npy")
y_val = np.load("../data/gold/y_val_labels.npy")
X_test = np.load("../data/gold/X_test_esm2.npy")
y_pred_nn = np.load("../data/gold/y_pred_nn.npy")

train_ids_labels = np.load("../data/gold/train_protein_ids.npy", allow_pickle=True)
val_ids_labels = np.load("../data/gold/val_protein_ids.npy", allow_pickle=True)
all_ids_emb = np.load("../data/gold/train_ids.npy", allow_pickle=True)
test_ids = np.load("../data/gold/test_protein_ids.npy", allow_pickle=True)

# Mapowanie
train_idx_emb = [np.where(all_ids_emb == pid)[0][0] for pid in train_ids_labels]
val_idx_emb = [np.where(all_ids_emb == pid)[0][0] for pid in val_ids_labels]
X_train = X_train[train_idx_emb]
X_val = X_val[val_idx_emb]

print(f"\n📊 Dataset sizes:")
print(f"  Train: X={X_train.shape}, y={y_train.shape}")
print(f"  Val: X={X_val.shape}, y={y_val.shape}")
print(f"  Test: {X_test.shape}")

# ========================================
# CZĘŚĆ 1: Trenowanie XGBoost
# ========================================
print("\n" + "=" * 80)
print("🌲 Trenowanie XGBoost...")
print("=" * 80)

clf = MultiOutputClassifier(xgb.XGBClassifier(
    tree_method='hist',      # 🔧 ZMIENIONE: 'hist' zamiast 'gpu_hist'
    device='cuda',           # GPU jest tu
    n_estimators=100, 
    max_depth=5, 
    learning_rate=0.1,
    random_state=42
))

clf.fit(X_train, y_train)
print("✅ XGBoost wytrenowany")

# Predykcja na validation
print("\n🧠 Predykcja XGBoost na validation...")
y_val_pred_xgb = np.array([p[:, 1] for p in clf.predict_proba(X_val)]).T

# Predykcja na test
print("🧠 Predykcja XGBoost na test...")
y_test_pred_xgb = np.array([p[:, 1] for p in clf.predict_proba(X_test)]).T

print(f"✅ XGBoost predictions: val={y_val_pred_xgb.shape}, test={y_test_pred_xgb.shape}")

# ========================================
# CZĘŚĆ 2: NN Predictions na Validation
# ========================================
print("\n" + "=" * 80)
print("🧠 Wczytywanie NN predictions dla validation...")
print("=" * 80)

import torch
import torch.nn as nn

class ProteinClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(320, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(0.3),
            nn.Linear(512, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(0.3),
            nn.Linear(1024, 1500)
        )
    def forward(self, x): 
        return self.net(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ProteinClassifier().to(device)
model.load_state_dict(torch.load("../models/protein_nn.pth"))
model.eval()

with torch.no_grad():
    y_val_pred_nn = torch.sigmoid(model(torch.FloatTensor(X_val).to(device))).cpu().numpy()

y_test_pred_nn = y_pred_nn  # Already computed

print(f"✅ NN predictions: val={y_val_pred_nn.shape}, test={y_test_pred_nn.shape}")

# ========================================
# CZĘŚĆ 3: Optymalizacja wag ensemble
# ========================================
print("\n" + "=" * 80)
print("⚖️ Optymalizacja wag ensemble na validation...")
print("=" * 80)

# Test różne kombinacje wag
weight_combinations = [
    (0.5, 0.5),
    (0.6, 0.4),
    (0.7, 0.3),
    (0.8, 0.2),
    (0.9, 0.1),
    (0.4, 0.6),
    (0.3, 0.7),
]

# Test thresholdy
thresholds = [0.01, 0.03, 0.05, 0.08, 0.1, 0.15, 0.2]

best_f1 = 0
best_weights = (0.7, 0.3)
best_threshold = 0.05

results = []

for w_nn, w_xgb in weight_combinations:
    y_val_ensemble = (w_nn * y_val_pred_nn) + (w_xgb * y_val_pred_xgb)
    
    for threshold in thresholds:
        y_pred_binary = (y_val_ensemble > threshold).astype(int)
        f1 = f1_score(y_val, y_pred_binary, average='samples', zero_division=0)
        
        results.append({
            'w_nn': w_nn,
            'w_xgb': w_xgb,
            'threshold': threshold,
            'f1': f1
        })
        
        if f1 > best_f1:
            best_f1 = f1
            best_weights = (w_nn, w_xgb)
            best_threshold = threshold

# Print top 10
print("\n🏆 Top 10 konfiguracji:")
sorted_results = sorted(results, key=lambda x: x['f1'], reverse=True)
for i, r in enumerate(sorted_results[:10], 1):
    print(f"  {i:2d}. NN={r['w_nn']:.1f}, XGB={r['w_xgb']:.1f}, "
          f"T={r['threshold']:.2f} → F1={r['f1']:.4f}")

print(f"\n✅ BEST CONFIG:")
print(f"  Weights: NN={best_weights[0]:.1f}, XGB={best_weights[1]:.1f}")
print(f"  Threshold: {best_threshold}")
print(f"  Val F1: {best_f1:.4f}")

# Save config
config = {
    'w_nn': best_weights[0],
    'w_xgb': best_weights[1],
    'threshold': best_threshold,
    'val_f1': best_f1
}

with open('../models/ensemble_config.json', 'w') as f:
    json.dump(config, f, indent=2)

# ========================================
# CZĘŚĆ 4: Final Ensemble na Test Set
# ========================================
print("\n" + "=" * 80)
print("🎯 Generowanie finalnego ensemble dla test set...")
print("=" * 80)

y_test_final = (best_weights[0] * y_test_pred_nn) + (best_weights[1] * y_test_pred_xgb)

print(f"✅ Final predictions: {y_test_final.shape}")

# ========================================
# CZĘŚĆ 5: Zapisywanie Submission
# ========================================
print("\n" + "=" * 80)
print("💾 Zapisywanie submission...")
print("=" * 80)

# Sprawdź statystyki przed zapisem
print(f"\n📊 Statystyki predykcji:")
print(f"  Min score: {y_test_final.min():.4f}")
print(f"  Max score: {y_test_final.max():.4f}")
print(f"  Mean score: {y_test_final.mean():.4f}")
print(f"  Scores > {best_threshold}: {(y_test_final > best_threshold).sum():,}")

# Zapisz submission
submission_lines = []
total_predictions = 0

for i, prot_id in enumerate(test_ids):
    row = y_test_final[i]
    indices = np.where(row > best_threshold)[0]
    
    # Sort by score (descending)
    sorted_indices = indices[np.argsort(-row[indices])]
    
    # Limit to top 1500 per protein (competition requirement)
    sorted_indices = sorted_indices[:1500]
    
    for idx in sorted_indices:
        submission_lines.append(f"{prot_id}\t{top_terms[idx]}\t{row[idx]:.3f}\n")
        total_predictions += 1

# Write submission
with open("submission_final.tsv", "w") as f:
    f.writelines(submission_lines)

print(f"\n✅ Submission zapisany: submission_final.tsv")
print(f"  Total lines: {total_predictions:,}")
print(f"  Avg predictions per protein: {total_predictions / len(test_ids):.1f}")

# ========================================
# CZĘŚĆ 6: Validation Summary
# ========================================
print("\n" + "=" * 80)
print("📈 PODSUMOWANIE")
print("=" * 80)

print(f"\n🎯 Best Configuration:")
print(f"  NN Weight: {best_weights[0]}")
print(f"  XGBoost Weight: {best_weights[1]}")
print(f"  Threshold: {best_threshold}")
print(f"  Validation F1: {best_f1:.4f}")

print(f"\n📁 Pliki wygenerowane:")
print(f"  submission_final.tsv - Gotowy do uploadu na Kaggle!")
print(f"  ../models/ensemble_config.json - Najlepsza konfiguracja")

print("\n" + "=" * 80)
print("✅ WSZYSTKO GOTOWE! MOŻESZ SUBMITOWAĆ!")
print("=" * 80)
# Out:
# ================================================================================
# 🎯 ENSEMBLE & SUBMISSION GENERATION
# ================================================================================
#
# 📊 Dataset sizes:
#   Train: X=(70043, 320), y=(70043, 1500)
#   Val: X=(12361, 320), y=(12361, 1500)
#   Test: (224309, 320)
#
# ================================================================================
# 🌲 Trenowanie XGBoost...
# ================================================================================
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[1], line 52
#      41 print("=" * 80)
#      43 clf = MultiOutputClassifier(xgb.XGBClassifier(
#      44     tree_method='gpu_hist',
#      45     n_estimators=100,
#    (...)     49     random_state=42
#      50 ))
# ---> 52 clf.fit(X_train, y_train)
#      53 print("✅ XGBoost wytrenowany")
#      55 # Predykcja na validation
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/multioutput.py:543, in MultiOutputClassifier.fit(self, X, Y, sample_weight, **fit_params)
#     517 def fit(self, X, Y, sample_weight=None, **fit_params):
#     518     """Fit the model to data matrix X and targets Y.
#     519
#     520     Parameters
#    (...)    541         Returns a fitted instance.
#     542     """
# --> 543     super().fit(X, Y, sample_weight=sample_weight, **fit_params)
#     544     self.classes_ = [estimator.classes_ for estimator in self.estimators_]
#     545     return self
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/multioutput.py:274, in _MultiOutputEstimator.fit(self, X, y, sample_weight, **fit_params)
#     271     if sample_weight is not None:
#     272         routed_params.estimator.fit["sample_weight"] = sample_weight
# --> 274 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     275     delayed(_fit_estimator)(
#     276         self.estimator, X, y[:, i], **routed_params.estimator.fit
#     277     )
#     278     for i in range(y.shape[1])
#     279 )
#     281 if hasattr(self.estimators_[0], "n_features_in_"):
#     282     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/sklearn/multioutput.py:63, in _fit_estimator(estimator, X, y, sample_weight, **fit_params)
#      61     estimator.fit(X, y, sample_weight=sample_weight, **fit_params)
#      62 else:
# ---> 63     estimator.fit(X, y, **fit_params)
#      64 return estimator
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)   1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/training.py:199, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     197 if cb_container.before_iteration(bst, i, dtrain, evals):
#     198     break
# --> 199 bst.update(dtrain, iteration=i, fobj=obj)
#     200 if cb_container.after_iteration(bst, i, dtrain, evals):
#     201     break
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/core.py:2433, in Booster.update(self, dtrain, iteration, fobj)
#    2430 self._assign_dmatrix_features(dtrain)
#    2432 if fobj is None:
# -> 2433     _check_call(
#    2434         _LIB.XGBoosterUpdateOneIter(
#    2435             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2436         )
#    2437     )
#    2438 else:
#    2439     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~/projects/bioinformatics-portfolio/projects/02-cafa6-protein-function-prediction/.venv/lib/python3.12/site-packages/xgboost/core.py:323, in _check_call(ret)
#     312 """Check the return value of C API call
#     313
#     314 This function will raise exception when error occurs.
#    (...)    320     return value from API calls
#     321 """
#     322 if ret != 0:
# --> 323     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: Invalid Input: 'gpu_hist', valid values are: {'approx', 'auto', 'exact', 'hist'}
